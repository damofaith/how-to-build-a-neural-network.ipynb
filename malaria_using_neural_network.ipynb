# %% [markdown]
# <a href="https://colab.research.google.com/github/damofaith/how-to-build-a-neural-network.ipynb/blob/main/malaria_using_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#data handling
import pandas as pd
import numpy as np

#data visualization
import matplotlib.pyplot as plt
import seaborn as sns

#preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,label_binarize
from sklearn.preprocessing import MinMaxScaler

#classification
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
#set path to the data file.
data_file='https://raw.githubusercontent.com/vappiah/Machine-Learning-Tutorials/main/datasets/malaria_clin_data.csv'

#read the data with pandas
dataframe=pd.read_csv(data_file)

# %% [markdown]
# Data Cleaning

# %%
#finding the number of rows and columns in the dataframe
dataframe.shape
# Out:
# (2207, 34)

# %%
dataframe.head(n=5)
# Out:
#    SampleID consent_given  location  Enrollment_Year bednet fever_symptom  \
# 0  CCS20043           yes  Navrongo             2004    NaN           Yes
# 1  CCS20102           yes  Navrongo             2004    NaN           Yes
# 2  CCS20106           yes  Navrongo             2004    NaN           Yes
# 3  CCS20147           yes  Navrongo             2004    NaN           Yes
# 4  CCS20170           yes  Navrongo             2004    NaN           Yes
#
#    temperature         Suspected_Organism Suspected_infection       RDT  ...  \
# 0         38.0  Not Known / Missing entry                 NaN  Positive  ...
# 1         38.2  Not Known / Missing entry                 NaN  Positive  ...
# 2         37.7  Not Known / Missing entry                 NaN  Positive  ...
# 3         37.7  Not Known / Missing entry                 NaN  Positive  ...
# 4         37.1  Not Known / Missing entry                 NaN  Positive  ...
#
#   platelet_count platelet_distr_width mean_platelet_vl  neutrophils_percent  \
# 0          156.0                  8.2              6.8                 61.8
# 1           55.0                 16.5              7.6                 68.5
# 2           20.0                  2.3              5.9                 32.8
# 3          132.0                 17.2              6.2                 82.6
# 4           85.0                 16.1              6.8                 83.7
#
#   lymphocytes_percent mixed_cells_percent neutrophils_count  \
# 0                31.7                 6.5               3.6
# 1                23.6                 7.9               5.4
# 2                53.3                13.9               2.8
# 3                11.5                 5.9              13.2
# 4                11.3                 5.0               3.8
#
#    lymphocytes_count  mixed_cells_count  RBC_dist_width_Percent
# 0                1.8                0.3                    19.0
# 1                1.8                0.6                    14.4
# 2                4.3                1.1                    18.0
# 3                1.8                0.9                    13.7
# 4                0.5                0.2                    15.0
#
# [5 rows x 34 columns]

# %%
dataframe.columns
# Out:
# Index(['SampleID', 'consent_given', 'location', 'Enrollment_Year', 'bednet',
#        'fever_symptom', 'temperature', 'Suspected_Organism',
#        'Suspected_infection', 'RDT', 'Blood_culture', 'Urine_culture',
#        'Taq_man_PCR', 'parasite_density', 'Microscopy', 'Laboratory_Results',
#        'Clinical_Diagnosis', 'wbc_count', 'rbc_count', 'hb_level',
#        'hematocrit', 'mean_cell_volume', 'mean_corp_hb', 'mean_cell_hb_conc',
#        'platelet_count', 'platelet_distr_width', 'mean_platelet_vl',
#        'neutrophils_percent', 'lymphocytes_percent', 'mixed_cells_percent',
#        'neutrophils_count', 'lymphocytes_count', 'mixed_cells_count',
#        'RBC_dist_width_Percent'],
#       dtype='object')

# %%
#we are interested in the columns : 'Clinical_diagnosis' up to 'RBC_dist_width_Percent'
#meaning we will subset the data from column 16 - the last column
subset=dataframe.iloc[:,16:]

# %%
# handling missing values
# drop / remove all rows with missing values
subset.dropna(inplace=True)

# %%
#Let us get the different malaria outcomes.
#The outcomes will be our labels/classes in the data

subset['Clinical_Diagnosis'].unique()
# Out:
# array(['Severe Malaria', 'Uncomplicated Malaria', 'Non-malaria Infection'],
#       dtype=object)

# %% [markdown]
# data preprocessing

# %%
# separate the labels/classes from the features/measurement
X=subset.iloc[:,1:]
y=subset.iloc[:,0]

# %% [markdown]
# Encode labels
#
# The labels for this data are categorical and we therefore have to convert them to numeric forms. This is referred to as encoding. Machine learning models usually require input data to be in numeric forms, hence we encoding the labels.

# %%
#let's encode target labels (y). We will use onehot encoding.

label_encoder=LabelEncoder()
label_encoder.fit(y)
y=label_encoder.transform(y)
labels=label_encoder.classes_
classes=np.unique(y)
y=label_binarize(y,classes=np.unique(y))
nclasses=y.shape[1]

# %% [markdown]
# Data Splitting
# Data is split into three: training, validation and test sets
# -training set is used for training.
# -validation set is used for evaluating the model during training.
# -test set is used to test the model after training and tuning has been completed.

# %%
#split data into training,validation and test sets

#split the data into training and test sets
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

#split the training set into two (training and validation)
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.2)

# %% [markdown]
# Data Normalization
# Data normalization is done so that the values are in the same range. This will improve model performance and avoid bias.
# Normalization is performed separately on each data set. This is done to prevent data leakage.

# %%
min_max_scaler=MinMaxScaler()
X_train=min_max_scaler.fit_transform(X_train)
X_val=min_max_scaler.fit_transform(X_val)
X_test=min_max_scaler.fit_transform(X_test)

# %% [markdown]
# Building Neural Network

# %%
#define model
model = Sequential()

#hidden layer 1
model.add(Dense(40, input_dim=X_train.shape[1], activation='relu'))

#hidden layer 2
model.add(Dense(20, activation='relu'))

#output layer
model.add(Dense(nclasses, activation='softmax'))

#define optimizer and learning rate. We will use Adam optimizer
opt_adam = keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss=tf.keras.losses.CategoricalCrossentropy(), optimizer=opt_adam, metrics=[keras.metrics.CategoricalAccuracy()])

# %%
#fit the model to the training data
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32,epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 44/44 [==============================] - 2s 12ms/step - loss: 0.9926 - categorical_accuracy: 0.4627 - val_loss: 0.8926 - val_categorical_accuracy: 0.5478
# Epoch 2/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.8580 - categorical_accuracy: 0.5801 - val_loss: 0.7540 - val_categorical_accuracy: 0.6493
# Epoch 3/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.7400 - categorical_accuracy: 0.6809 - val_loss: 0.6523 - val_categorical_accuracy: 0.7159
# Epoch 4/200
# 44/44 [==============================] - 0s 5ms/step - loss: 0.6530 - categorical_accuracy: 0.7491 - val_loss: 0.5903 - val_categorical_accuracy: 0.7362
# Epoch 5/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.5988 - categorical_accuracy: 0.7614 - val_loss: 0.5475 - val_categorical_accuracy: 0.7797
# Epoch 6/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.5645 - categorical_accuracy: 0.7658 - val_loss: 0.5368 - val_categorical_accuracy: 0.7884
# Epoch 7/200
# 44/44 [==============================] - 0s 5ms/step - loss: 0.5438 - categorical_accuracy: 0.7752 - val_loss: 0.5559 - val_categorical_accuracy: 0.7710
# Epoch 8/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.5337 - categorical_accuracy: 0.7774 - val_loss: 0.5413 - val_categorical_accuracy: 0.7855
# Epoch 9/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.5197 - categorical_accuracy: 0.7810 - val_loss: 0.5752 - val_categorical_accuracy: 0.7681
# Epoch 10/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.5110 - categorical_accuracy: 0.7868 - val_loss: 0.5593 - val_categorical_accuracy: 0.7768
# Epoch 11/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.5008 - categorical_accuracy: 0.7803 - val_loss: 0.6176 - val_categorical_accuracy: 0.7652
# Epoch 12/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4955 - categorical_accuracy: 0.7912 - val_loss: 0.6284 - val_categorical_accuracy: 0.7652
# Epoch 13/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4969 - categorical_accuracy: 0.7868 - val_loss: 0.5768 - val_categorical_accuracy: 0.7884
# Epoch 14/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4894 - categorical_accuracy: 0.7933 - val_loss: 0.6320 - val_categorical_accuracy: 0.7681
# Epoch 15/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.4788 - categorical_accuracy: 0.7991 - val_loss: 0.6230 - val_categorical_accuracy: 0.7681
# Epoch 16/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4782 - categorical_accuracy: 0.7991 - val_loss: 0.6220 - val_categorical_accuracy: 0.7681
# Epoch 17/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4742 - categorical_accuracy: 0.8006 - val_loss: 0.6173 - val_categorical_accuracy: 0.7652
# Epoch 18/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4751 - categorical_accuracy: 0.7991 - val_loss: 0.6104 - val_categorical_accuracy: 0.7768
# Epoch 19/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4677 - categorical_accuracy: 0.8107 - val_loss: 0.5616 - val_categorical_accuracy: 0.7913
# Epoch 20/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4631 - categorical_accuracy: 0.8078 - val_loss: 0.6451 - val_categorical_accuracy: 0.7623
# Epoch 21/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4580 - categorical_accuracy: 0.8115 - val_loss: 0.6334 - val_categorical_accuracy: 0.7681
# Epoch 22/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4594 - categorical_accuracy: 0.8100 - val_loss: 0.6321 - val_categorical_accuracy: 0.7681
# Epoch 23/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4515 - categorical_accuracy: 0.8180 - val_loss: 0.6172 - val_categorical_accuracy: 0.7797
# Epoch 24/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4495 - categorical_accuracy: 0.8129 - val_loss: 0.6410 - val_categorical_accuracy: 0.7652
# Epoch 25/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4507 - categorical_accuracy: 0.8122 - val_loss: 0.5907 - val_categorical_accuracy: 0.7739
# Epoch 26/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4454 - categorical_accuracy: 0.8144 - val_loss: 0.6151 - val_categorical_accuracy: 0.7681
# Epoch 27/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4419 - categorical_accuracy: 0.8129 - val_loss: 0.6192 - val_categorical_accuracy: 0.7768
# Epoch 28/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4440 - categorical_accuracy: 0.8209 - val_loss: 0.6656 - val_categorical_accuracy: 0.7623
# Epoch 29/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4422 - categorical_accuracy: 0.8180 - val_loss: 0.5666 - val_categorical_accuracy: 0.7942
# Epoch 30/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4414 - categorical_accuracy: 0.8165 - val_loss: 0.6743 - val_categorical_accuracy: 0.7594
# Epoch 31/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4321 - categorical_accuracy: 0.8245 - val_loss: 0.6143 - val_categorical_accuracy: 0.7768
# Epoch 32/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4305 - categorical_accuracy: 0.8245 - val_loss: 0.6739 - val_categorical_accuracy: 0.7623
# Epoch 33/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4426 - categorical_accuracy: 0.8122 - val_loss: 0.6166 - val_categorical_accuracy: 0.7710
# Epoch 34/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4269 - categorical_accuracy: 0.8223 - val_loss: 0.6042 - val_categorical_accuracy: 0.7797
# Epoch 35/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4216 - categorical_accuracy: 0.8238 - val_loss: 0.6882 - val_categorical_accuracy: 0.7565
# Epoch 36/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4290 - categorical_accuracy: 0.8223 - val_loss: 0.6340 - val_categorical_accuracy: 0.7739
# Epoch 37/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4166 - categorical_accuracy: 0.8267 - val_loss: 0.5885 - val_categorical_accuracy: 0.7884
# Epoch 38/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4186 - categorical_accuracy: 0.8310 - val_loss: 0.6983 - val_categorical_accuracy: 0.7362
# Epoch 39/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4191 - categorical_accuracy: 0.8260 - val_loss: 0.5634 - val_categorical_accuracy: 0.8058
# Epoch 40/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4161 - categorical_accuracy: 0.8238 - val_loss: 0.6268 - val_categorical_accuracy: 0.7681
# Epoch 41/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4121 - categorical_accuracy: 0.8252 - val_loss: 0.6332 - val_categorical_accuracy: 0.7710
# Epoch 42/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4116 - categorical_accuracy: 0.8260 - val_loss: 0.6044 - val_categorical_accuracy: 0.7797
# Epoch 43/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4092 - categorical_accuracy: 0.8281 - val_loss: 0.5919 - val_categorical_accuracy: 0.7826
# Epoch 44/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4141 - categorical_accuracy: 0.8318 - val_loss: 0.6233 - val_categorical_accuracy: 0.7710
# Epoch 45/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4051 - categorical_accuracy: 0.8332 - val_loss: 0.6788 - val_categorical_accuracy: 0.7565
# Epoch 46/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4071 - categorical_accuracy: 0.8354 - val_loss: 0.5852 - val_categorical_accuracy: 0.7884
# Epoch 47/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4016 - categorical_accuracy: 0.8361 - val_loss: 0.6208 - val_categorical_accuracy: 0.7768
# Epoch 48/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4027 - categorical_accuracy: 0.8332 - val_loss: 0.6353 - val_categorical_accuracy: 0.7739
# Epoch 49/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4034 - categorical_accuracy: 0.8347 - val_loss: 0.6100 - val_categorical_accuracy: 0.7768
# Epoch 50/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4023 - categorical_accuracy: 0.8332 - val_loss: 0.6484 - val_categorical_accuracy: 0.7681
# Epoch 51/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.4024 - categorical_accuracy: 0.8245 - val_loss: 0.6184 - val_categorical_accuracy: 0.7739
# Epoch 52/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3934 - categorical_accuracy: 0.8368 - val_loss: 0.6203 - val_categorical_accuracy: 0.7739
# Epoch 53/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3943 - categorical_accuracy: 0.8325 - val_loss: 0.6172 - val_categorical_accuracy: 0.7710
# Epoch 54/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3923 - categorical_accuracy: 0.8405 - val_loss: 0.6954 - val_categorical_accuracy: 0.7391
# Epoch 55/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3984 - categorical_accuracy: 0.8339 - val_loss: 0.6076 - val_categorical_accuracy: 0.7710
# Epoch 56/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3940 - categorical_accuracy: 0.8376 - val_loss: 0.5835 - val_categorical_accuracy: 0.7913
# Epoch 57/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3893 - categorical_accuracy: 0.8426 - val_loss: 0.6235 - val_categorical_accuracy: 0.7652
# Epoch 58/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3869 - categorical_accuracy: 0.8434 - val_loss: 0.6317 - val_categorical_accuracy: 0.7681
# Epoch 59/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3899 - categorical_accuracy: 0.8405 - val_loss: 0.6167 - val_categorical_accuracy: 0.7710
# Epoch 60/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3880 - categorical_accuracy: 0.8368 - val_loss: 0.6513 - val_categorical_accuracy: 0.7594
# Epoch 61/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3877 - categorical_accuracy: 0.8390 - val_loss: 0.5850 - val_categorical_accuracy: 0.7826
# Epoch 62/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3889 - categorical_accuracy: 0.8354 - val_loss: 0.6290 - val_categorical_accuracy: 0.7652
# Epoch 63/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3858 - categorical_accuracy: 0.8426 - val_loss: 0.6507 - val_categorical_accuracy: 0.7565
# Epoch 64/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3867 - categorical_accuracy: 0.8354 - val_loss: 0.6284 - val_categorical_accuracy: 0.7652
# Epoch 65/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3837 - categorical_accuracy: 0.8390 - val_loss: 0.6176 - val_categorical_accuracy: 0.7681
# Epoch 66/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3818 - categorical_accuracy: 0.8448 - val_loss: 0.6023 - val_categorical_accuracy: 0.7681
# Epoch 67/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3797 - categorical_accuracy: 0.8434 - val_loss: 0.5643 - val_categorical_accuracy: 0.7826
# Epoch 68/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3844 - categorical_accuracy: 0.8383 - val_loss: 0.5842 - val_categorical_accuracy: 0.7739
# Epoch 69/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3807 - categorical_accuracy: 0.8426 - val_loss: 0.6576 - val_categorical_accuracy: 0.7507
# Epoch 70/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3803 - categorical_accuracy: 0.8325 - val_loss: 0.6013 - val_categorical_accuracy: 0.7710
# Epoch 71/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3748 - categorical_accuracy: 0.8426 - val_loss: 0.6918 - val_categorical_accuracy: 0.7362
# Epoch 72/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3829 - categorical_accuracy: 0.8347 - val_loss: 0.6831 - val_categorical_accuracy: 0.7420
# Epoch 73/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3769 - categorical_accuracy: 0.8426 - val_loss: 0.5741 - val_categorical_accuracy: 0.7797
# Epoch 74/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3741 - categorical_accuracy: 0.8455 - val_loss: 0.6281 - val_categorical_accuracy: 0.7623
# Epoch 75/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3733 - categorical_accuracy: 0.8455 - val_loss: 0.6390 - val_categorical_accuracy: 0.7594
# Epoch 76/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3749 - categorical_accuracy: 0.8426 - val_loss: 0.6352 - val_categorical_accuracy: 0.7565
# Epoch 77/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3733 - categorical_accuracy: 0.8455 - val_loss: 0.6252 - val_categorical_accuracy: 0.7623
# Epoch 78/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3732 - categorical_accuracy: 0.8455 - val_loss: 0.6178 - val_categorical_accuracy: 0.7652
# Epoch 79/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3734 - categorical_accuracy: 0.8434 - val_loss: 0.5779 - val_categorical_accuracy: 0.7739
# Epoch 80/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3753 - categorical_accuracy: 0.8405 - val_loss: 0.6408 - val_categorical_accuracy: 0.7536
# Epoch 81/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3683 - categorical_accuracy: 0.8448 - val_loss: 0.6297 - val_categorical_accuracy: 0.7623
# Epoch 82/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3756 - categorical_accuracy: 0.8419 - val_loss: 0.6093 - val_categorical_accuracy: 0.7623
# Epoch 83/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3722 - categorical_accuracy: 0.8448 - val_loss: 0.5541 - val_categorical_accuracy: 0.7826
# Epoch 84/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3693 - categorical_accuracy: 0.8455 - val_loss: 0.6010 - val_categorical_accuracy: 0.7652
# Epoch 85/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3674 - categorical_accuracy: 0.8477 - val_loss: 0.6080 - val_categorical_accuracy: 0.7623
# Epoch 86/200
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3671 - categorical_accuracy: 0.8506 - val_loss: 0.6086 - val_categorical_accuracy: 0.7565
# Epoch 87/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3697 - categorical_accuracy: 0.8419 - val_loss: 0.6010 - val_categorical_accuracy: 0.7623
# Epoch 88/200
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3644 - categorical_accuracy: 0.8477 - val_loss: 0.5870 - val_categorical_accuracy: 0.7710
# Epoch 89/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3652 - categorical_accuracy: 0.8470 - val_loss: 0.5959 - val_categorical_accuracy: 0.7623
# Epoch 90/200
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3631 - categorical_accuracy: 0.8484 - val_loss: 0.5678 - val_categorical_accuracy: 0.7826
# Epoch 91/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3627 - categorical_accuracy: 0.8492 - val_loss: 0.6469 - val_categorical_accuracy: 0.7362
# Epoch 92/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3702 - categorical_accuracy: 0.8463 - val_loss: 0.5989 - val_categorical_accuracy: 0.7681
# Epoch 93/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3702 - categorical_accuracy: 0.8361 - val_loss: 0.6549 - val_categorical_accuracy: 0.7333
# Epoch 94/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3615 - categorical_accuracy: 0.8506 - val_loss: 0.5941 - val_categorical_accuracy: 0.7710
# Epoch 95/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3639 - categorical_accuracy: 0.8477 - val_loss: 0.5843 - val_categorical_accuracy: 0.7739
# Epoch 96/200
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3681 - categorical_accuracy: 0.8426 - val_loss: 0.5847 - val_categorical_accuracy: 0.7739
# Epoch 97/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3617 - categorical_accuracy: 0.8528 - val_loss: 0.6206 - val_categorical_accuracy: 0.7478
# Epoch 98/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3608 - categorical_accuracy: 0.8419 - val_loss: 0.6302 - val_categorical_accuracy: 0.7478
# Epoch 99/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3610 - categorical_accuracy: 0.8484 - val_loss: 0.5851 - val_categorical_accuracy: 0.7710
# Epoch 100/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3620 - categorical_accuracy: 0.8448 - val_loss: 0.6263 - val_categorical_accuracy: 0.7652
# Epoch 101/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3578 - categorical_accuracy: 0.8506 - val_loss: 0.6488 - val_categorical_accuracy: 0.7449
# Epoch 102/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3583 - categorical_accuracy: 0.8513 - val_loss: 0.6331 - val_categorical_accuracy: 0.7594
# Epoch 103/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3579 - categorical_accuracy: 0.8535 - val_loss: 0.6349 - val_categorical_accuracy: 0.7536
# Epoch 104/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3606 - categorical_accuracy: 0.8492 - val_loss: 0.6126 - val_categorical_accuracy: 0.7623
# Epoch 105/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3543 - categorical_accuracy: 0.8528 - val_loss: 0.5952 - val_categorical_accuracy: 0.7710
# Epoch 106/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3609 - categorical_accuracy: 0.8470 - val_loss: 0.5460 - val_categorical_accuracy: 0.7884
# Epoch 107/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3665 - categorical_accuracy: 0.8383 - val_loss: 0.5211 - val_categorical_accuracy: 0.8087
# Epoch 108/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3583 - categorical_accuracy: 0.8484 - val_loss: 0.6458 - val_categorical_accuracy: 0.7478
# Epoch 109/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3592 - categorical_accuracy: 0.8419 - val_loss: 0.6684 - val_categorical_accuracy: 0.7391
# Epoch 110/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3541 - categorical_accuracy: 0.8470 - val_loss: 0.6154 - val_categorical_accuracy: 0.7565
# Epoch 111/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3544 - categorical_accuracy: 0.8528 - val_loss: 0.5691 - val_categorical_accuracy: 0.7884
# Epoch 112/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3562 - categorical_accuracy: 0.8463 - val_loss: 0.6112 - val_categorical_accuracy: 0.7681
# Epoch 113/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3547 - categorical_accuracy: 0.8550 - val_loss: 0.5877 - val_categorical_accuracy: 0.7739
# Epoch 114/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3585 - categorical_accuracy: 0.8426 - val_loss: 0.5944 - val_categorical_accuracy: 0.7681
# Epoch 115/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3532 - categorical_accuracy: 0.8506 - val_loss: 0.7034 - val_categorical_accuracy: 0.7333
# Epoch 116/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3519 - categorical_accuracy: 0.8506 - val_loss: 0.6256 - val_categorical_accuracy: 0.7507
# Epoch 117/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3602 - categorical_accuracy: 0.8470 - val_loss: 0.6449 - val_categorical_accuracy: 0.7507
# Epoch 118/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3517 - categorical_accuracy: 0.8528 - val_loss: 0.5873 - val_categorical_accuracy: 0.7739
# Epoch 119/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3515 - categorical_accuracy: 0.8535 - val_loss: 0.5623 - val_categorical_accuracy: 0.7826
# Epoch 120/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3557 - categorical_accuracy: 0.8448 - val_loss: 0.5703 - val_categorical_accuracy: 0.7768
# Epoch 121/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3508 - categorical_accuracy: 0.8564 - val_loss: 0.6221 - val_categorical_accuracy: 0.7565
# Epoch 122/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3488 - categorical_accuracy: 0.8542 - val_loss: 0.5964 - val_categorical_accuracy: 0.7768
# Epoch 123/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3568 - categorical_accuracy: 0.8506 - val_loss: 0.5866 - val_categorical_accuracy: 0.7710
# Epoch 124/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3494 - categorical_accuracy: 0.8506 - val_loss: 0.6068 - val_categorical_accuracy: 0.7652
# Epoch 125/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3480 - categorical_accuracy: 0.8521 - val_loss: 0.6086 - val_categorical_accuracy: 0.7710
# Epoch 126/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3471 - categorical_accuracy: 0.8535 - val_loss: 0.5563 - val_categorical_accuracy: 0.7884
# Epoch 127/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3507 - categorical_accuracy: 0.8542 - val_loss: 0.6436 - val_categorical_accuracy: 0.7507
# Epoch 128/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3513 - categorical_accuracy: 0.8542 - val_loss: 0.5944 - val_categorical_accuracy: 0.7739
# Epoch 129/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3458 - categorical_accuracy: 0.8542 - val_loss: 0.6905 - val_categorical_accuracy: 0.7333
# Epoch 130/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3452 - categorical_accuracy: 0.8564 - val_loss: 0.6080 - val_categorical_accuracy: 0.7681
# Epoch 131/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3496 - categorical_accuracy: 0.8484 - val_loss: 0.6139 - val_categorical_accuracy: 0.7681
# Epoch 132/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3429 - categorical_accuracy: 0.8557 - val_loss: 0.6671 - val_categorical_accuracy: 0.7391
# Epoch 133/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3476 - categorical_accuracy: 0.8535 - val_loss: 0.6438 - val_categorical_accuracy: 0.7681
# Epoch 134/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3443 - categorical_accuracy: 0.8528 - val_loss: 0.6155 - val_categorical_accuracy: 0.7681
# Epoch 135/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3435 - categorical_accuracy: 0.8571 - val_loss: 0.5864 - val_categorical_accuracy: 0.7768
# Epoch 136/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3480 - categorical_accuracy: 0.8470 - val_loss: 0.6076 - val_categorical_accuracy: 0.7710
# Epoch 137/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3579 - categorical_accuracy: 0.8521 - val_loss: 0.5559 - val_categorical_accuracy: 0.7971
# Epoch 138/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3519 - categorical_accuracy: 0.8506 - val_loss: 0.5545 - val_categorical_accuracy: 0.7913
# Epoch 139/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3497 - categorical_accuracy: 0.8579 - val_loss: 0.6629 - val_categorical_accuracy: 0.7594
# Epoch 140/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3453 - categorical_accuracy: 0.8564 - val_loss: 0.6496 - val_categorical_accuracy: 0.7565
# Epoch 141/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3425 - categorical_accuracy: 0.8557 - val_loss: 0.6349 - val_categorical_accuracy: 0.7652
# Epoch 142/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3442 - categorical_accuracy: 0.8571 - val_loss: 0.6112 - val_categorical_accuracy: 0.7739
# Epoch 143/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3442 - categorical_accuracy: 0.8564 - val_loss: 0.6590 - val_categorical_accuracy: 0.7478
# Epoch 144/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3408 - categorical_accuracy: 0.8608 - val_loss: 0.6100 - val_categorical_accuracy: 0.7681
# Epoch 145/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3383 - categorical_accuracy: 0.8593 - val_loss: 0.6372 - val_categorical_accuracy: 0.7536
# Epoch 146/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3440 - categorical_accuracy: 0.8521 - val_loss: 0.6184 - val_categorical_accuracy: 0.7710
# Epoch 147/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3377 - categorical_accuracy: 0.8564 - val_loss: 0.6079 - val_categorical_accuracy: 0.7797
# Epoch 148/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3472 - categorical_accuracy: 0.8557 - val_loss: 0.6401 - val_categorical_accuracy: 0.7652
# Epoch 149/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3480 - categorical_accuracy: 0.8521 - val_loss: 0.6903 - val_categorical_accuracy: 0.7362
# Epoch 150/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3440 - categorical_accuracy: 0.8550 - val_loss: 0.6814 - val_categorical_accuracy: 0.7449
# Epoch 151/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3416 - categorical_accuracy: 0.8593 - val_loss: 0.6372 - val_categorical_accuracy: 0.7681
# Epoch 152/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3430 - categorical_accuracy: 0.8550 - val_loss: 0.6147 - val_categorical_accuracy: 0.7652
# Epoch 153/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3379 - categorical_accuracy: 0.8557 - val_loss: 0.5572 - val_categorical_accuracy: 0.7971
# Epoch 154/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3349 - categorical_accuracy: 0.8644 - val_loss: 0.6527 - val_categorical_accuracy: 0.7623
# Epoch 155/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3416 - categorical_accuracy: 0.8579 - val_loss: 0.6488 - val_categorical_accuracy: 0.7652
# Epoch 156/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3373 - categorical_accuracy: 0.8586 - val_loss: 0.7018 - val_categorical_accuracy: 0.7362
# Epoch 157/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3377 - categorical_accuracy: 0.8579 - val_loss: 0.6307 - val_categorical_accuracy: 0.7594
# Epoch 158/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3384 - categorical_accuracy: 0.8564 - val_loss: 0.6443 - val_categorical_accuracy: 0.7594
# Epoch 159/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3405 - categorical_accuracy: 0.8564 - val_loss: 0.5827 - val_categorical_accuracy: 0.7942
# Epoch 160/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3386 - categorical_accuracy: 0.8542 - val_loss: 0.6171 - val_categorical_accuracy: 0.7739
# Epoch 161/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3338 - categorical_accuracy: 0.8571 - val_loss: 0.5975 - val_categorical_accuracy: 0.7826
# Epoch 162/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3350 - categorical_accuracy: 0.8600 - val_loss: 0.6704 - val_categorical_accuracy: 0.7594
# Epoch 163/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3395 - categorical_accuracy: 0.8557 - val_loss: 0.6683 - val_categorical_accuracy: 0.7536
# Epoch 164/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3372 - categorical_accuracy: 0.8550 - val_loss: 0.6481 - val_categorical_accuracy: 0.7565
# Epoch 165/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3338 - categorical_accuracy: 0.8608 - val_loss: 0.6203 - val_categorical_accuracy: 0.7739
# Epoch 166/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3494 - categorical_accuracy: 0.8593 - val_loss: 0.6319 - val_categorical_accuracy: 0.7623
# Epoch 167/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3310 - categorical_accuracy: 0.8651 - val_loss: 0.6289 - val_categorical_accuracy: 0.7710
# Epoch 168/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3324 - categorical_accuracy: 0.8615 - val_loss: 0.5912 - val_categorical_accuracy: 0.7826
# Epoch 169/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3323 - categorical_accuracy: 0.8586 - val_loss: 0.7017 - val_categorical_accuracy: 0.7391
# Epoch 170/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3301 - categorical_accuracy: 0.8709 - val_loss: 0.6283 - val_categorical_accuracy: 0.7739
# Epoch 171/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3341 - categorical_accuracy: 0.8666 - val_loss: 0.5888 - val_categorical_accuracy: 0.7826
# Epoch 172/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3318 - categorical_accuracy: 0.8564 - val_loss: 0.6373 - val_categorical_accuracy: 0.7681
# Epoch 173/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3307 - categorical_accuracy: 0.8586 - val_loss: 0.6761 - val_categorical_accuracy: 0.7449
# Epoch 174/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3362 - categorical_accuracy: 0.8615 - val_loss: 0.6282 - val_categorical_accuracy: 0.7739
# Epoch 175/200
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3290 - categorical_accuracy: 0.8644 - val_loss: 0.6780 - val_categorical_accuracy: 0.7420
# Epoch 176/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3304 - categorical_accuracy: 0.8637 - val_loss: 0.5743 - val_categorical_accuracy: 0.7913
# Epoch 177/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3290 - categorical_accuracy: 0.8651 - val_loss: 0.5634 - val_categorical_accuracy: 0.7855
# Epoch 178/200
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3286 - categorical_accuracy: 0.8687 - val_loss: 0.6486 - val_categorical_accuracy: 0.7594
# Epoch 179/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3306 - categorical_accuracy: 0.8666 - val_loss: 0.5919 - val_categorical_accuracy: 0.7855
# Epoch 180/200
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3334 - categorical_accuracy: 0.8637 - val_loss: 0.6373 - val_categorical_accuracy: 0.7710
# Epoch 181/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3298 - categorical_accuracy: 0.8680 - val_loss: 0.6159 - val_categorical_accuracy: 0.7797
# Epoch 182/200
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3304 - categorical_accuracy: 0.8608 - val_loss: 0.5722 - val_categorical_accuracy: 0.7942
# Epoch 183/200
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3326 - categorical_accuracy: 0.8615 - val_loss: 0.6225 - val_categorical_accuracy: 0.7710
# Epoch 184/200
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3345 - categorical_accuracy: 0.8622 - val_loss: 0.6443 - val_categorical_accuracy: 0.7710
# Epoch 185/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3332 - categorical_accuracy: 0.8637 - val_loss: 0.7176 - val_categorical_accuracy: 0.7420
# Epoch 186/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3261 - categorical_accuracy: 0.8666 - val_loss: 0.6057 - val_categorical_accuracy: 0.7884
# Epoch 187/200
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3439 - categorical_accuracy: 0.8608 - val_loss: 0.6564 - val_categorical_accuracy: 0.7565
# Epoch 188/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3287 - categorical_accuracy: 0.8666 - val_loss: 0.6495 - val_categorical_accuracy: 0.7710
# Epoch 189/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3276 - categorical_accuracy: 0.8651 - val_loss: 0.6406 - val_categorical_accuracy: 0.7681
# Epoch 190/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3229 - categorical_accuracy: 0.8716 - val_loss: 0.6422 - val_categorical_accuracy: 0.7739
# Epoch 191/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3319 - categorical_accuracy: 0.8622 - val_loss: 0.6223 - val_categorical_accuracy: 0.7739
# Epoch 192/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3339 - categorical_accuracy: 0.8608 - val_loss: 0.6593 - val_categorical_accuracy: 0.7623
# Epoch 193/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3296 - categorical_accuracy: 0.8608 - val_loss: 0.6200 - val_categorical_accuracy: 0.7797
# Epoch 194/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3225 - categorical_accuracy: 0.8644 - val_loss: 0.6882 - val_categorical_accuracy: 0.7536
# Epoch 195/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3270 - categorical_accuracy: 0.8687 - val_loss: 0.5901 - val_categorical_accuracy: 0.7942
# Epoch 196/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3279 - categorical_accuracy: 0.8637 - val_loss: 0.5778 - val_categorical_accuracy: 0.7913
# Epoch 197/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3363 - categorical_accuracy: 0.8629 - val_loss: 0.5970 - val_categorical_accuracy: 0.7826
# Epoch 198/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3272 - categorical_accuracy: 0.8651 - val_loss: 0.6493 - val_categorical_accuracy: 0.7623
# Epoch 199/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3242 - categorical_accuracy: 0.8695 - val_loss: 0.6733 - val_categorical_accuracy: 0.7652
# Epoch 200/200
# 44/44 [==============================] - 0s 3ms/step - loss: 0.3229 - categorical_accuracy: 0.8658 - val_loss: 0.6266 - val_categorical_accuracy: 0.7797

# %%
# summarize history for accuracy
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model performance')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='lower right')
plt.show()
